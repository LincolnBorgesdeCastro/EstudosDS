# %% [markdown]
# # <font color='blue'>Data Science Academy - Visualização de Dados e Design de Dashboards</font>

# %% [markdown]
# ****** Este Jupyter Notebook foi atualizado para a versão 3.6.1. da Linguagem Python em 10/08/2017 ******

# %% [markdown]
# ## ScatterPlot 3D e Plotly

# %%
from matplotlib import pyplot
# %matplotlib inline

# %%
# Range de 0 - 541
X = range(0, 541)

# Gera valores de y com base em valores de x usando list compreheension
Y = [i*i for i in X]

# Gera o gráfico
pyplot.plot(X, Y, '-')

# Labels e título
pyplot.title('Plotting x*x')
pyplot.xlabel('Eixo X')
pyplot.ylabel('Eixo Y')

# Salva o chart como png
pyplot.savefig('Simple.png')

# Mostra o gráfico
pyplot.show()

# %%
# Plot 3D
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
import matplotlib.pyplot as plt

fig = plt.figure()
ax = fig.gca(projection='3d')

# Criando a curva do eixo z
x = np.linspace(0, 1, 100)
y = np.sin(x * -1 * np.pi) / 2 + 0.5

ax.plot(x, y, zs = 0, zdir = 'z', label = 'Curva randômica, apenas para o eixo z')

# Cores
colors = ('r', 'g', 'k', 'b')

for c in colors:
    x = np.random.sample(42)
    y = np.random.sample(42)
    ax.scatter(x, y, 1, zdir='x', c=c)

# Legenda
ax.legend()

# Eixos x, y e z
ax.set_xlim3d(0, 1)
ax.set_ylim3d(0, 1)
ax.set_zlim3d(0, 1)

# Mostra o chart
plt.show()

# %%
# Plotly
# Galeria: https://plot.ly/python/

# !pip install plotly

# Importa o plotly
import plotly
import plotly.plotly as py

# Importa todos os tipos de gráficos
from plotly.graph_objs import *

# Definindo API Key, credenciais e streaming como definido em https://plot.ly/python/getting-started
plotly.tools.set_credentials_file(username='[username]', 
                                  api_key = '[apikey]', 
                                  stream_ids = ['[streamingkey1]', '[streamingkey2]'])

# Cria um dataset
trace0 = Scatter(
    x = [5, 10, 15, 20],
    y = [20, 40, 35, 16]
)

data = Data([trace0])

# Define a url e abre o gráfico no browser
unique_url = py.plot(data, filename = 'basic-line')
# Out:
# ...
# Aw, snap! We don't have an account for '[username]'. Want to try again? You can authenticate with your email address or username. Sign in is not case sensitive.
#
# Don't have an account? plot.ly
#
# Questions? support@plot.ly

# %% [markdown]
# # Fim
