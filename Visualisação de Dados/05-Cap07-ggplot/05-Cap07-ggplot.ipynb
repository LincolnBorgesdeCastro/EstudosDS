# %% [markdown]
# # <font color='blue'>Data Science Academy - Visualização de Dados e Design de Dashboards</font>

# %% [markdown]
# ## Gráficos em Python com ggplot

# %%
# %matplotlib inline

# %%
# !pip install ggplot
# Out:
# Requirement already satisfied: ggplot in /anaconda/lib/python3.5/site-packages
# Requirement already satisfied: statsmodels in /anaconda/lib/python3.5/site-packages (from ggplot)
# Requirement already satisfied: six in /anaconda/lib/python3.5/site-packages (from ggplot)
# Requirement already satisfied: brewer2mpl in /anaconda/lib/python3.5/site-packages (from ggplot)
# Requirement already satisfied: numpy in /anaconda/lib/python3.5/site-packages (from ggplot)
# Requirement already satisfied: matplotlib in /anaconda/lib/python3.5/site-packages (from ggplot)
# Requirement already satisfied: pandas in /anaconda/lib/python3.5/site-packages (from ggplot)
# Requirement already satisfied: patsy>=0.4 in /anaconda/lib/python3.5/site-packages (from ggplot)
# Requirement already satisfied: scipy in /anaconda/lib/python3.5/site-packages (from ggplot)
# Requirement already satisfied: cycler in /anaconda/lib/python3.5/site-packages (from ggplot)
# Requirement already satisfied: python-dateutil in /anaconda/lib/python3.5/site-packages (from matplotlib->ggplot)
# Requirement already satisfied: pytz in /anaconda/lib/python3.5/site-packages (from matplotlib->ggplot)
# Requirement already satisfied: pyparsing!=2.0.4,!=2.1.2,>=1.5.6 in /anaconda/lib/python3.5/site-packages (from matplotlib->ggplot)

# %%
from ggplot import *

# %%
print (ggplot(mtcars, aes('mpg', 'qsec')) + \
       geom_point(colour = 'steelblue') + \
       scale_x_continuous(breaks = [10, 20, 30],  \
                          labels = ["Ruim", "Pk", "Bom"]))
# Out:
# <ggplot: (292567009)>

# %%
print (ggplot(meat, aes('date','beef')) + \
       geom_line(color = 'black') + \
       scale_x_date(breaks = date_breaks('7 years'), labels = '%b %Y') + \
       scale_y_continuous(labels = 'comma'))
# Out:
# <ggplot: (-9223372036560906261)>

# %%
import matplotlib.pyplot as plt
from matplotlib.dates import YearLocator, DateFormatter
from ggplot import meat
tick_every_n = YearLocator(7)
date_formatter = DateFormatter('%b %Y')
x = meat.date
y = meat.beef
fig, ax = plt.subplots()
ax.plot(x, y, 'black')
ax.xaxis.set_major_locator(tick_every_n)
ax.xaxis.set_major_formatter(date_formatter)
fig.autofmt_xdate()
plt.show()

# %%
print (ggplot(meat, aes('date','beef * 2000')) + \
       geom_line(color = 'coral') + \
       scale_x_date(breaks = date_breaks('36 months'), labels = '%Y') + \
       scale_y_continuous(labels = 'millions'))
# Out:
# <ggplot: (-9223372036561753561)>

# %% [markdown]
# # Fim
